# %%
import pandas as pd

# %%
from bertopic import BERTopic
# Out:
# WARNING:tensorflow:From c:\Users\yzhen\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data = pd.read_csv('balanced_data.csv')

# %%
tops = data[data['category'] == 'Shirts/Tops']
reviews = tops['text'].tolist()
ratings = tops['rating'].astype(int).tolist()

# %%
reviews = [str(i) for i in reviews]

# %%
tops.columns
# Out:
# Index(['Unnamed: 0', 'rating', 'parent_asin', 'text', 'title',
#        'average_rating', 'category'],
#       dtype='object')

# %%
topic_model = BERTopic(language="english", verbose=True)
topics, probs = topic_model.fit_transform(reviews)
# Out:
# 2025-11-22 10:58:07,041 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/1066 [00:00<?, ?it/s]
# 2025-11-22 11:02:33,303 - BERTopic - Embedding - Completed ✓
# 2025-11-22 11:02:33,311 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-11-22 11:02:51,860 - BERTopic - Dimensionality - Completed ✓
# 2025-11-22 11:02:51,868 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-11-22 11:03:02,977 - BERTopic - Cluster - Completed ✓
# 2025-11-22 11:03:03,010 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-22 11:03:05,754 - BERTopic - Representation - Completed ✓

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                       Name  \
# 0       -1  13247                        -1_shirt_the_and_is
# 1        0   1448                    0_dress_dresses_this_im
# 2        1    439                1_wash_after_washed_washing
# 3        2    431                             2_la_es_el_muy
# 4        3    430            3_blouse_blouses_beautiful_this
# ..     ...    ...                                        ...
# 384    383     10      383_34smart_phonewallet34_sesm_shabby
# 385    384     10  384_dinosaur_niece_granddaughter_adorable
# 386    385     10          385_black_navy_feellook_umbrellas
# 387    386     10             386_month_baby_nephew_adorable
# 388    387     10             387_pretty_smalll_dear_shipper
#
#                                         Representation  \
# 0     [shirt, the, and, is, it, to, size, but, of, in]
# 1    [dress, dresses, this, im, am, love, pockets, ...
# 2    [wash, after, washed, washing, shrunk, first, ...
# 3    [la, es, el, muy, de, que, calidad, tela, lo, ...
# 4    [blouse, blouses, beautiful, this, pretty, bus...
# ..                                                 ...
# 384  [34smart, phonewallet34, sesm, shabby, lingeri...
# 385  [dinosaur, niece, granddaughter, adorable, bal...
# 386  [black, navy, feellook, umbrellas, illustratio...
# 387  [month, baby, nephew, adorable, 1yo, itmbr, ho...
# 388  [pretty, smalll, dear, shipper, toooooo, pando...
#
#                                    Representative_Docs
# 0    [Shirts did not fit to size.I bought 5 of them...
# 1    [LOVE this dress!!!, I love this dress!, Love ...
# 2    [Poor quality - shrunk up after the first wash...
# 3    [mala calidad, la talla no es la que correspon...
# 4             [Nice blouse, cute blouse., cute blouse]
# ..                                                 ...
# 384  [A little smaller than I was hoping, but it sh...
# 385  [Cute dinosaur designs that were given to a di...
# 386  [I'm giving this a three because while it's no...
# 387  [This is adorable and so cute.  Fits perfectly...
# 388  [It's not as big as I thought it would be. But...
#
# [389 rows x 5 columns]
