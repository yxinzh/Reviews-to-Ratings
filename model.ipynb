# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic

# %%
data = pd.read_csv('balanced_data.csv')

# %%
tops = data[data['category'] == 'Shirts/Tops']
reviews = tops['text'].tolist()
ratings = tops['rating'].astype(int).tolist()

# %%
reviews = [str(i) for i in reviews]

# %%
tops.columns
# Out:
# Index(['Unnamed: 0', 'rating', 'parent_asin', 'text', 'title',
#        'average_rating', 'category'],
#       dtype='object')

# %%
topic_model = BERTopic(language="english", verbose=True)
topics, probs = topic_model.fit_transform(reviews)
# Out:
# 2025-11-22 11:17:24,294 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/1066 [00:00<?, ?it/s]
# 2025-11-22 11:24:13,444 - BERTopic - Embedding - Completed ✓
# 2025-11-22 11:24:13,444 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-11-22 11:24:28,618 - BERTopic - Dimensionality - Completed ✓
# 2025-11-22 11:24:28,618 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-11-22 11:24:34,871 - BERTopic - Cluster - Completed ✓
# 2025-11-22 11:24:34,887 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-22 11:24:36,403 - BERTopic - Representation - Completed ✓

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                        Name  \
# 0       -1  12529                         -1_shirt_and_the_it
# 1        0   1565                     0_dress_dresses_this_am
# 2        1   1193                     1_top_tops_bottoms_cute
# 3        2    437                              2_la_es_el_muy
# 4        3    432             3_blouse_blouses_beautiful_this
# ..     ...    ...                                         ...
# 388    387     10           387_tshirt_ad_waffleknit_memories
# 389    388     10             388_sizebr_smaller_clean_seemed
# 390    389     10        389_suggest_snugly_wondering_leather
# 391    390     10              390_cheaply_made_17_affordable
# 392    391     10  391_slim_easythanks_boxglad_relaxedregular
#
#                                         Representation  \
# 0    [shirt, and, the, it, is, to, but, of, size, not]
# 1    [dress, dresses, this, am, im, pockets, love, ...
# 2    [top, tops, bottoms, cute, bottom, this, is, b...
# 3    [la, es, el, muy, de, que, calidad, tela, lo, ...
# 4    [blouse, blouses, beautiful, this, pretty, bus...
# ..                                                 ...
# 388  [tshirt, ad, waffleknit, memories, likey, huuu...
# 389  [sizebr, smaller, clean, seemed, ended, us, bi...
# 390  [suggest, snugly, wondering, leather, taking, ...
# 391  [cheaply, made, 17, affordable, tell, expect, ...
# 392  [slim, easythanks, boxglad, relaxedregular, or...
#
#                                    Representative_Docs
# 0    [Shirt looks like the picture! Would have boug...
# 1    [In love with this dress!!!!, I love this dres...
# 2                     [Great top, Cute top, Cute top.]
# 3    [No me gustó la calidad de la tela, mala calid...
# 4             [Nice blouse, cute blouse, cute blouse.]
# ..                                                 ...
# 388  [T-shirt has a great feel, and washes nicely. ...
# 389  [Size was much smaller than expected., It ende...
# 390  [Nice material.  If you want it to fit snugly,...
# 391  [Very cheaply made, Very cheaply made, Very ch...
# 392  [If that is the slim, I wonder how the ordinar...
#
# [393 rows x 5 columns]

# %%
tops['topic'] = topics
tops['topic_probs'] = probs

# %%
tops.shape
# Out:
# (34082, 9)

# %%
#remove topic = -1 because those are outliers and should be ignored
tops_cleaned = tops[tops['topic'] != -1]
